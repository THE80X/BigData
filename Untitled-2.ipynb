# %% [markdown]
# # Практика 2
# Выполнено Студентом группы ИКБО-27-22 Соловьевом Иваном

# %% [markdown]
# ## Задание 1
# Найти и выгрузить многомерные данные (с большим количеством признаков – столбцов) с использованием библиотеки pandas. В отчёте описать найденные данные

# %%
import pandas

data = pandas.read_csv('data_Net_generation.csv')
data
# Out:
#       Month  all fuels (utility-scale) thousand megawatthours  \
# 0    Sep-23                                       358136.2599
# 1    Aug-23                                       423934.2574
# 2    Jul-23                                       425611.3284
# 3    Jun-23                                       356672.3849
# 4    May-23                                       327532.6236
# ..      ...                                               ...
# 268  May-01                                       300491.6210
# 269  Apr-01                                       278078.8710
# 270  Mar-01                                       300706.5440
# 271  Feb-01                                       282940.1980
# 272  Jan-01                                       332493.1600
#
#      coal thousand megawatthours  natural gas thousand megawatthours  \
# 0                    60005.67580                         164466.3568
# 1                    78184.50094                         199993.0422
# 2                    78909.85665                         200506.7592
# 3                    57697.75156                         161692.7028
# 4                    43852.22406                         137795.2922
# ..                           ...                                 ...
# 268                 151592.91400                          50934.2050
# 269                 140670.65400                          45842.7460
# 270                 155269.01100                          44364.4140
# 271                 149735.48400                          37966.9270
# 272                 177287.11100                          42388.6630
#
#      nuclear thousand megawatthours  \
# 0                         65559.710
# 1                         69744.023
# 2                         69887.588
# 3                         64965.076
# 4                         61472.883
# ..                              ...
# 268                       61512.445
# 269                       56003.026
# 270                       62140.712
# 271                       61272.407
# 272                       68707.077
#
#      conventional hydroelectric thousand megawatthours  \
# 0                                          16496.04043
# 1                                          21145.86624
# 2                                          21237.80849
# 3                                          19470.63281
# 4                                          27479.13413
# ..                                                 ...
# 268                                        19175.63500
# 269                                        18012.99400
# 270                                        20477.18900
# 271                                        17472.88900
# 272                                        18852.04800
#
#      wind thousand megawatthours  all solar thousand megawatthours
# 0                    28193.29153                       22192.58066
# 1                    28504.16694                       25350.26673
# 2                    27867.90946                       26538.55725
# 3                    27505.93547                       25034.48613
# 4                    32018.24592                       24462.37510
# ..                           ...                               ...
# 268                    635.02900                               NaN
# 269                    684.69500                               NaN
# 270                    532.12000                               NaN
# 271                    431.24200                               NaN
# 272                    389.25000                               NaN
#
# [273 rows x 8 columns]

# %% [markdown]
# ## Задание 2
# Вывести информацию о данных при помощи методов .info(), .head(). Проверить данные на наличие пустых значений. В случае их наличия удалить данные строки или интерполировать пропущенные значения. При необходимости дополнительно предобработать данные для дальнейшей работы с ними.
